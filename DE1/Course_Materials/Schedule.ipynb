# %% [markdown]
# # Schedule of due dates for ECE 5760: Spring 2026

# %% [markdown]
# All of your lab reports will be turned in electronically via Canvas. These will be due *before the beginning of your next lab section.* Your final project status reports will also be turned in electronically via Canvas.
#
# Each of your laboratory checkoffs should be demonstrated by the *end* of your assigned lab section to the instructor or a TA.

# %% [markdown]
# | Week of . . . | Checkoff due<br>at end of lab section| Deliverable due<br>at beginning of lab section |
# | :-- | :-- | ----: |
# | 1/19   | Lab 1: Week 1 | Read the course policy page, come with questions
# | 1/26   | Lab 1: Week 2 |
# | 2/2   | Lab 1: Week 3 |
# | 2/9   | Lab 2: Week 1 | Lab 1 report
# | 2/16  | Lab 2: Week 2 |
# | 2/23  | Lab 2: Week 3 |
# | 3/2   | Lab 3: Week 1 | Lab 2 report
# | 3/9   | Lab 3: Week 2 | Final project proposal
# | 3/16  | Lab 3: Week 3 |
# | 3/23  | Project: Week 1 | Lab 3 report <br> Project status report
# | 3/30  | (Spring break)|
# | 4/6   | Project: Week 2 | Project status report
# | 4/13  | Project: Week 3 | Project status report
# | 4/20  | Project: Week 4 | Project status report
# | 4/27  | Project: Week 5 | Project status report
# | 5/4   | Final project demonstrations |
# | TBD.  |  | Final project webpage

# %% [markdown]
# ***
