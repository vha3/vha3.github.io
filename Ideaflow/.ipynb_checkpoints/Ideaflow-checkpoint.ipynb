# %% [markdown]
# # Ideaflow license landing page
# #### [V. Hunter Adams](https://vanhunteradams.com)
#
# If you find the software that uses the Ideaflow license useful, please consider thanking me by offering your thoughts (anonymously or otherwise) on the material linked below. I value your input regardless of your familiarity with the material, and will endeavor to present the material for which I request feedback such that it does not require domain expertise to assess. Feedback need not be technical in nature.
#
# Please also find a feedback form linked below.
#
# These links are not static, and may be updated as the material for which I'd appreciate feedback changes.

# %% [markdown]
# ***

# %% [markdown]
# ## Material for review, and a feedback form

# %% [markdown]
# #### [Material for review](https://vanhunteradams.com/Talks/Natural_Computing.pdf)

# %% [markdown]
# #### [Feedback form](https://forms.gle/BspBV5j8gJ48Vw6b8)

# %% [markdown]
# ***

# %% [markdown]
# [About the Ideaflow license](./About.html)
